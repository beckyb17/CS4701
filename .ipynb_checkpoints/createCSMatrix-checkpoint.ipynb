# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re

# %%
df = pd.read_csv('final_taylor_swift_lyrics.tsv', sep='\t')

# %%
print(df.head())
# Out:
#    index  album song_title                                              lyric  \
# 0      0  Lover     Lover                                           [Verse 1]
# 1      0  Lover     Lover   We could leave the Christmas lights up 'til Ja...
# 2      0  Lover     Lover            And this is our place, we make the rules
# 3      0  Lover     Lover   And there's a dazzling haze, a mysterious way ...
# 4      0  Lover     Lover            Have I known you 20 seconds or 20 years?
#
#    line_number release_date
# 0            0   2019-08-16
# 1            1   2019-08-16
# 2            2   2019-08-16
# 3            3   2019-08-16
# 4            4   2019-08-16

# %%
df.to_dict(orient = 'records')
# Out:
# [{'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': '[Verse 1]',
#   'line_number': 0,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "We could leave the Christmas lights up 'til January",
#   'line_number': 1,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'And this is our place, we make the rules',
#   'line_number': 2,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "And there's a dazzling haze, a mysterious way about you, dear",
#   'line_number': 3,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Have I known you 20 seconds or 20 years?',
#   'line_number': 4,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': '[Chorus]',
#   'line_number': 5,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Can I go where you go?',
#   'line_number': 6,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Can we always be this close?',
#   'line_number': 7,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Forever and ever, ah',
#   'line_number': 8,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Take me out, and take me home',
#   'line_number': 9,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "You're my, my, my, my lover",
#   'line_number': 10,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': '[Verse 2]',
#   'line_number': 11,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'We could let our friends crash in the living room',
#   'line_number': 12,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'This is our place, we make the call',
#   'line_number': 13,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "And I'm highly suspicious that everyone who sees you wants you",
#   'line_number': 14,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "I've loved you three summers now, honey, but I want 'em all",
#   'line_number': 15,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': '[Chorus]',
#   'line_number': 16,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Can I go where you go?',
#   'line_number': 17,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Can we always be this close?',
#   'line_number': 18,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Forever and ever, ah',
#   'line_number': 19,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Take me out, and take me home (Forever and ever)',
#   'line_number': 20,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "You're my, my, my, my lover",
#   'line_number': 21,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': '[Bridge]',
#   'line_number': 22,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Ladies and gentlemen, will you please stand?',
#   'line_number': 23,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'With every guitar string scar on my hand',
#   'line_number': 24,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'I take this magnetic force of a man to be my lover',
#   'line_number': 25,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "My heart's been borrowed and yours has been blue",
#   'line_number': 26,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "All's well that ends well to end up with you",
#   'line_number': 27,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Swear to be overdramatic and true to my lover',
#   'line_number': 28,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "And you'll save all your dirtiest jokes for me",
#   'line_number': 29,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "And at every table, I'll save you a seat, lover",
#   'line_number': 30,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': '[Chorus]',
#   'line_number': 31,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Can I go where you go?',
#   'line_number': 32,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Can we always be this close?',
#   'line_number': 33,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Forever and ever, ah',
#   'line_number': 34,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': 'Take me out, and take me home (Forever and ever)',
#   'line_number': 35,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "You're my, my, my, my",
#   'line_number': 36,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "Oh, you're my, my, my, my",
#   'line_number': 37,
#   'release_date': '2019-08-16'},
#  {'index': 0,
#   'album': 'Lover',
#   'song_title': 'Lover ',
#   'lyric': "Darling, you're my, my, my, my lover",
#   'line_number': 38,
#   'release_date': '2019-08-16'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Verse 1]',
#   'line_number': 0,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't like your little games",
#   'line_number': 1,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "Don't like your tilted stage",
#   'line_number': 2,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'The role you made me play',
#   'line_number': 3,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "Of the fool, no, I don't like you",
#   'line_number': 4,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't like your perfect crime",
#   'line_number': 5,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'How you laugh when you lie',
#   'line_number': 6,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'You said the gun was mine',
#   'line_number': 7,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "Isn't cool, no, I don't like you (Oh)",
#   'line_number': 8,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Pre-Chorus]',
#   'line_number': 9,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'But I got smarter, I got harder in the nick of time',
#   'line_number': 10,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Honey, I rose up from the dead, I do it all the time',
#   'line_number': 11,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I've got a list of names and yours is in red, underlined",
#   'line_number': 12,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'I check it once, then I check it twice, oh!',
#   'line_number': 13,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Chorus]',
#   'line_number': 14,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 15,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 16,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 17,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me—',
#   'line_number': 18,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 19,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 20,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 21,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 22,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Verse 2]',
#   'line_number': 23,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't like your kingdom keys",
#   'line_number': 24,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'They once belonged to me',
#   'line_number': 25,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'You asked me for a place to sleep',
#   'line_number': 26,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Locked me out and threw a feast (What?)',
#   'line_number': 27,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'The world moves on, another day, another drama, drama',
#   'line_number': 28,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'But not for me, not for me, all I think about is karma',
#   'line_number': 29,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "And then the world moves on, but one thing's for sure",
#   'line_number': 30,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "Maybe I got mine, but you'll all get yours",
#   'line_number': 31,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Pre-Chorus]',
#   'line_number': 32,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'But I got smarter, I got harder in the nick of time',
#   'line_number': 33,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Honey, I rose up from the dead, I do it all the time',
#   'line_number': 34,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I've got a list of names and yours is in red, underlined",
#   'line_number': 35,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'I check it once, then I check it twice, oh!',
#   'line_number': 36,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Chorus]',
#   'line_number': 37,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 38,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 39,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 40,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me—',
#   'line_number': 41,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 42,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 43,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 44,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 45,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Bridge]',
#   'line_number': 46,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't trust nobody and nobody trusts me",
#   'line_number': 47,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I'll be the actress starring in your bad dreams",
#   'line_number': 48,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't trust nobody and nobody trusts me",
#   'line_number': 49,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I'll be the actress starring in your bad dreams",
#   'line_number': 50,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't trust nobody and nobody trusts me",
#   'line_number': 51,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I'll be the actress starring in your bad dreams",
#   'line_number': 52,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I don't trust nobody and nobody trusts me",
#   'line_number': 53,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': "I'll be the actress starring in your bad dreams",
#   'line_number': 54,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '(Ooh, look what you made me do',
#   'line_number': 55,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 56,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 57,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me—',
#   'line_number': 58,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 59,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 60,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me—)',
#   'line_number': 61,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'I\'m sorry, the old Taylor can\'t come to the phone right now\t62\t2017-08-25\n1\treputation\tLook What You Made Me Do \tWhy? Oh, \'cause she\'s dead!" (Oh)',
#   'line_number': 63,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': '[Chorus]',
#   'line_number': 64,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 65,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 66,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 67,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me—',
#   'line_number': 68,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 69,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 70,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 71,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 72,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 73,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 74,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 75,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me—',
#   'line_number': 76,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Ooh, look what you made me do',
#   'line_number': 77,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you made me do',
#   'line_number': 78,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 79,
#   'release_date': '2017-08-25'},
#  {'index': 1,
#   'album': 'reputation',
#   'song_title': 'Look What You Made Me Do ',
#   'lyric': 'Look what you just made me do',
#   'line_number': 80,
#   'release_date': '2017-08-25'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Chorus: Taylor Swift & Future]',
#   'line_number': 0,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game',
#   'line_number': 1,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your first string',
#   'line_number': 2,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your A-Team (Whoa, whoa, whoa)',
#   'line_number': 3,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game, end game',
#   'line_number': 4,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Post-Chorus: Taylor Swift & Future]',
#   'line_number': 5,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Big reputation, big reputation',
#   'line_number': 6,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Ooh, you and me, we got big reputations, ah',
#   'line_number': 7,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'And you heard about me, ooh',
#   'line_number': 8,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I got some big enemies (Yeah)',
#   'line_number': 9,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Big reputation, big reputation',
#   'line_number': 10,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Ooh, you and me would be a big conversation, ah (Git, git)',
#   'line_number': 11,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'And I heard about you, ooh (Yeah)',
#   'line_number': 12,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'You like the bad ones, too',
#   'line_number': 13,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Verse 1: Future]',
#   'line_number': 14,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "You so dope, don't overdose, I’m so stoked, I need a toast",
#   'line_number': 15,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "We do the most, I'm in the Ghost like I'm whippin’ a boat",
#   'line_number': 16,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I got a reputation, girl that don't precede me (Yeah)",
#   'line_number': 17,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I'm one call away whenever you need me (Yeah)",
#   'line_number': 18,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I'm in a G5 (Yeah), come to the A-Side (Yeah)",
#   'line_number': 19,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I got a bad boy persona, that's what they like (What they like)",
#   'line_number': 20,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "You love it, I love it too 'cause you my type (You my type)",
#   'line_number': 21,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'You hold me down and I protect you with my life',
#   'line_number': 22,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Pre-Chorus: Taylor Swift & Future]',
#   'line_number': 23,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I don't wanna touch you, I don't wanna be",
#   'line_number': 24,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Just another ex-love you don’t wanna see',
#   'line_number': 25,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I don’t wanna miss you (I don't wanna miss you)",
#   'line_number': 26,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Like the other girls do',
#   'line_number': 27,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I don’t wanna hurt you, I just wanna be',
#   'line_number': 28,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Drinking on a beach with you all over me',
#   'line_number': 29,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I know what they all say (I know what they all say)',
#   'line_number': 30,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "But I ain't tryna play",
#   'line_number': 31,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Chorus: Taylor Swift]',
#   'line_number': 32,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game (End game)',
#   'line_number': 33,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your first string (First string)',
#   'line_number': 34,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your A-Team (A-Team)',
#   'line_number': 35,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game, end game',
#   'line_number': 36,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Verse 2: Ed Sheeran]',
#   'line_number': 37,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Knew her when I was young, reconnected when we were little bit older',
#   'line_number': 38,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Both sprung, I got issues and chips on both of my shoulders',
#   'line_number': 39,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "Reputation precedes me, in rumors, I'm knee-deep",
#   'line_number': 40,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "The truth is, it's easier to ignore it, believe me",
#   'line_number': 41,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "Even when we’d argue, we'd not do it for long",
#   'line_number': 42,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'And you understand the good and bad end up in the song',
#   'line_number': 43,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'For all your beautiful traits, and the way you do it with ease',
#   'line_number': 44,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'For all my flaws, paranoia, and insecurities',
#   'line_number': 45,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I've made mistakes and made some choices, that's hard to deny",
#   'line_number': 46,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'After the storm, something was born on the 4th of July',
#   'line_number': 47,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I've passed days without fun, this end game is the one",
#   'line_number': 48,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "With four words on the tip of my tongue, I'll never say it",
#   'line_number': 49,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Pre-Chorus: Taylor Swift]',
#   'line_number': 50,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I don't wanna touch you, I don't wanna be",
#   'line_number': 51,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "Just another ex-love you don't wanna see",
#   'line_number': 52,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I don't wanna miss you (I don't wanna miss you)",
#   'line_number': 53,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Like the other girls do',
#   'line_number': 54,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I don't wanna hurt you, I just wanna be",
#   'line_number': 55,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Drinking on a beach with you all over me',
#   'line_number': 56,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I know what they all say, yeah',
#   'line_number': 57,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "But I ain't tryna play",
#   'line_number': 58,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Chorus: Taylor Swift]',
#   'line_number': 59,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game (End game)',
#   'line_number': 60,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your first string (Wanna be your first string)',
#   'line_number': 61,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your A-Team (A-Team)',
#   'line_number': 62,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game, end game',
#   'line_number': 63,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Post-Chorus: Taylor Swift & Future]',
#   'line_number': 64,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Big reputation, big reputation',
#   'line_number': 65,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Ooh, you and me, we got big reputations, ah',
#   'line_number': 66,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'And you heard about me, ooh',
#   'line_number': 67,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I got some big enemies',
#   'line_number': 68,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Hey, big reputation, big reputation',
#   'line_number': 69,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'Ooh, you and me would be a big conversation, ah',
#   'line_number': 70,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'And I heard about you, ooh',
#   'line_number': 71,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'You like the bad ones, too',
#   'line_number': 72,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Verse 3: Taylor Swift]',
#   'line_number': 73,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I hit you like bang, we tried to forget it, but we just couldn't",
#   'line_number': 74,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "And I bury hatchets, but I keep maps of where I put 'em",
#   'line_number': 75,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "Reputation precedes me, they told you I'm crazy",
#   'line_number': 76,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "I swear I don't love the drama, it loves me",
#   'line_number': 77,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "And I can't let you go, your hand prints on my soul",
#   'line_number': 78,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "It's like your eyes are liquor, it's like your body is gold",
#   'line_number': 79,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "You've been calling my bluff on all my usual tricks",
#   'line_number': 80,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': "So here's the truth from my red lips",
#   'line_number': 81,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': '[Chorus: Taylor Swift, Future, & Ed Sheeran]',
#   'line_number': 82,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game (End game)',
#   'line_number': 83,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your first string (Me and you, first string)',
#   'line_number': 84,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your A-Team (Be your A-Team now, A-Team)',
#   'line_number': 85,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game, end game',
#   'line_number': 86,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game (Oh, I do)',
#   'line_number': 87,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your first string (First string)',
#   'line_number': 88,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your A-Team (A-Team)',
#   'line_number': 89,
#   'release_date': '2017-11-10'},
#  {'index': 2,
#   'album': 'reputation',
#   'song_title': 'End Game  (Ft.\xa0Ed\xa0Sheeran & Future)',
#   'lyric': 'I wanna be your end game, end game',
#   'line_number': 90,
#   'release_date': '2017-11-10'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Intro: Taylor Swift]',
#   'line_number': 0,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "I promise that you'll never find another like me",
#   'line_number': 1,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Verse 1: Taylor Swift]',
#   'line_number': 2,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "I know that I'm a handful, baby, uh",
#   'line_number': 3,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'I know I never think before I jump',
#   'line_number': 4,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "And you're the kind of guy the ladies want",
#   'line_number': 5,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "(And there's a lot of cool chicks out there)",
#   'line_number': 6,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'I know that I went psycho on the phone',
#   'line_number': 7,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'I never leave well enough alone',
#   'line_number': 8,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "And trouble's gonna follow where I go",
#   'line_number': 9,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "(And there's a lot of cool chicks out there)",
#   'line_number': 10,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Pre-Chorus: Taylor Swift]',
#   'line_number': 11,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'But one of these things is not like the others',
#   'line_number': 12,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Like a rainbow with all of the colors',
#   'line_number': 13,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Baby doll, when it comes to a lover',
#   'line_number': 14,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "I promise that you'll never find another like",
#   'line_number': 15,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Chorus: Taylor Swift]',
#   'line_number': 16,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Me-e-e, ooh-ooh-ooh-ooh',
#   'line_number': 17,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "I'm the only one of me",
#   'line_number': 18,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "Baby, that's the fun of me",
#   'line_number': 19,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Eeh-eeh-eeh, ooh-ooh-ooh-ooh',
#   'line_number': 20,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "You're the only one of you",
#   'line_number': 21,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "Baby, that's the fun of you",
#   'line_number': 22,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "And I promise that nobody's gonna love you like me-e-e",
#   'line_number': 23,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Verse 2: Brendon Urie & Taylor Swift]',
#   'line_number': 24,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'I know I tend to make it about me',
#   'line_number': 25,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'I know you never get just what you see',
#   'line_number': 26,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'But I will never bore you, baby',
#   'line_number': 27,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "(And there's a lot of lame guys out there)",
#   'line_number': 28,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'And when we had that fight out in the rain',
#   'line_number': 29,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'You ran after me and called my name',
#   'line_number': 30,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'I never wanna see you walk away',
#   'line_number': 31,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "(And there's a lot of lame guys out there)",
#   'line_number': 32,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Pre-Chorus: Taylor Swift & Brendon Urie, Brendon Urie]',
#   'line_number': 33,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "'Cause one of these things is not like the others",
#   'line_number': 34,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "Livin' in winter, I am your summer",
#   'line_number': 35,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Baby doll, when it comes to a lover',
#   'line_number': 36,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "I promise that you'll never find another like",
#   'line_number': 37,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': '[Chorus: Brendon Urie, Taylor Swift & Brendon Urie]',
#   'line_number': 38,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Me-e-e, ooh-ooh-ooh-ooh',
#   'line_number': 39,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': "I'm the only one of me",
#   'line_number': 40,
#   'release_date': '2019-04-26'},
#  {'index': 3,
#   'album': 'Lover',
#   'song_title': 'ME!  (Ft.\xa0Brendon\xa0Urie)',
#   'lyric': 'Let me keep you company',
# ...
#   'line_number': 57,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'No rules in breakable heaven',
#   'line_number': 58,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'But ooh, whoa oh',
#   'line_number': 59,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': "It's a cruel summer",
#   'line_number': 60,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'With you',
#   'line_number': 61,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': '[Outro]',
#   'line_number': 62,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': "I'm drunk in the back of the car",
#   'line_number': 63,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'And I cried like a baby coming home from the bar (Oh)',
#   'line_number': 64,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'Said, "I\'m fine," but it wasn\'t true',
#   'line_number': 65,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': "I don't wanna keep secrets just to keep you",
#   'line_number': 66,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'And I snuck in through the garden gate',
#   'line_number': 67,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'Every night that summer just to seal my fate (Oh)',
#   'line_number': 68,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'And I scream, "For whatever it\'s worth',
#   'line_number': 69,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': 'I love you, ain\'t that the worst thing you ever heard?"',
#   'line_number': 70,
#   'release_date': '2019-08-23'},
#  {'index': 14,
#   'album': 'Lover',
#   'song_title': 'Cruel Summer ',
#   'lyric': '(Yeah, yeah, yeah, yeah)',
#   'line_number': 71,
#   'release_date': '2019-08-23'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '[Verse 1]',
#   'line_number': 0,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Midnight',
#   'line_number': 1,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'You come and pick me up, no headlights',
#   'line_number': 2,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Long drive',
#   'line_number': 3,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Could end in burning flames or paradise',
#   'line_number': 4,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Fade into view, oh',
#   'line_number': 5,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "It's been a while since I have even heard from you",
#   'line_number': 6,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '(Heard from you)',
#   'line_number': 7,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "And I should just tell you to leave, 'cause I",
#   'line_number': 8,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Know exactly where it leads, but I',
#   'line_number': 9,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "Watch us go 'round and 'round each time",
#   'line_number': 10,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '[Chorus]',
#   'line_number': 11,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'You got that James Dean daydream look in your eye',
#   'line_number': 12,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And I got that red lip classic thing that you like',
#   'line_number': 13,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And when we go crashing down, we come back every time',
#   'line_number': 14,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "'Cause we never go out of style, we never go out of style",
#   'line_number': 15,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'You got that long hair, slicked back, white t-shirt',
#   'line_number': 16,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And I got that good girl faith and a tight little skirt',
#   'line_number': 17,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And when we go crashing down, we come back every time',
#   'line_number': 18,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "'Cause we never go out of style, we never go out of style",
#   'line_number': 19,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '[Verse 2]',
#   'line_number': 20,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'So it goes',
#   'line_number': 21,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "He can't keep his wild eyes on the road (Mmm)",
#   'line_number': 22,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Takes me home',
#   'line_number': 23,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "The lights are off, he's taking off his coat (Mmm, yeah)",
#   'line_number': 24,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'I say, "I heard, oh',
#   'line_number': 25,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'That you\'ve been out and about with some other girl"',
#   'line_number': 26,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Some other girl',
#   'line_number': 27,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'He says, "What you heard is true, but I',
#   'line_number': 28,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Can\'t stop thinking \'bout you," and I',
#   'line_number': 29,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'I said, "I\'ve been there too a few times"',
#   'line_number': 30,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '[Chorus]',
#   'line_number': 31,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "'Cause you got that James Dean daydream look in your eye",
#   'line_number': 32,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And I got that red lip classic thing that you like',
#   'line_number': 33,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And when we go crashing down, we come back every time',
#   'line_number': 34,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "'Cause we never go out of style, we never go out of style",
#   'line_number': 35,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'You got that long hair, slicked back, white t-shirt',
#   'line_number': 36,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And I got that good girl faith and a tight little skirt',
#   'line_number': 37,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '(A tight little skirt)',
#   'line_number': 38,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And when we go crashing down, we come back every time',
#   'line_number': 39,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "'Cause we never go out of style (we never go, we never go)",
#   'line_number': 40,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'We never go out of style',
#   'line_number': 41,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '[Bridge]',
#   'line_number': 42,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Take me home',
#   'line_number': 43,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Just take me home',
#   'line_number': 44,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Yeah, just take me home',
#   'line_number': 45,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Oh-oh, whoa-oh, oh',
#   'line_number': 46,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '(Out of style)',
#   'line_number': 47,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': '[Chorus]',
#   'line_number': 48,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'Oh, you got that James Dean daydream look in your eye',
#   'line_number': 49,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And I got that red lip classic thing that you like',
#   'line_number': 50,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'And when we go crashing down (And when we go)',
#   'line_number': 51,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': 'We come back every time',
#   'line_number': 52,
#   'release_date': '2014-10-27'},
#  {'index': 15,
#   'album': '1989 (Deluxe)',
#   'song_title': 'Style ',
#   'lyric': "'Cause we never go out of style, we never go out of style",
#   'line_number': 53,
#   'release_date': '2014-10-27'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': '[Verse 1]',
#   'line_number': 0,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': "Betty, I won't make assumptions",
#   'line_number': 1,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'About why you switched your homeroom, but',
#   'line_number': 2,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': "I think it's 'cause of\u2005me",
#   'line_number': 3,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Betty,\u2005one time I\u2005was riding on my skateboard',
#   'line_number': 4,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'When I\u2005passed your house',
#   'line_number': 5,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': "It's like I couldn't breathe",
#   'line_number': 6,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': '[Pre-Chorus]',
#   'line_number': 7,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'You heard the rumors from Inez',
#   'line_number': 8,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': "You can't believe a word she says",
#   'line_number': 9,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Most times, but this time it was true',
#   'line_number': 10,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'The worst thing that I ever did',
#   'line_number': 11,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Was what I did to you',
#   'line_number': 12,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': '[Chorus]',
#   'line_number': 13,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'But if I just showed up at your party',
#   'line_number': 14,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Would you have me? Would you want me?',
#   'line_number': 15,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Would you tell me to go fuck myself',
#   'line_number': 16,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Or lead me to the garden?',
#   'line_number': 17,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'In the garden, would you trust me',
#   'line_number': 18,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'If I told you it was just a summer thing?',
#   'line_number': 19,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': "I'm only seventeen, I don't know anything",
#   'line_number': 20,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'But I know I miss you',
#   'line_number': 21,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': '[Verse 2]',
#   'line_number': 22,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Betty, I know where it all went wrong',
#   'line_number': 23,
#   'release_date': '2020-07-24'},
#  {'index': 16,
#   'album': 'folklore',
#   'song_title': '\u200bbetty ',
#   'lyric': 'Your favorite song was playing',
#   'line_number': 24,
#   'release_date': '2020-07-24'},
#  ...]

# %%
df_dict = df.to_dict(orient = 'records')

# %%
#song to index maps song titles to their index
#index dic maps song index to a list of its lyrics

song_to_index = {}
index_dic = {}
for i in df_dict:
    index = i['index']
    lyric = i['lyric']
    if index in index_dic:
        index_dic[index].append(lyric)
    else:
        index_dic[index] = [lyric]
        title = i['song_title']
        song_to_index[title] = index

# %%
num_songs = len(song_to_index)

# %%
print(index_dic[1])
# Out:
# ['[Verse 1]', "I don't like your little games", "Don't like your tilted stage", 'The role you made me play', "Of the fool, no, I don't like you", "I don't like your perfect crime", 'How you laugh when you lie', 'You said the gun was mine', "Isn't cool, no, I don't like you (Oh)", '[Pre-Chorus]', 'But I got smarter, I got harder in the nick of time', 'Honey, I rose up from the dead, I do it all the time', "I've got a list of names and yours is in red, underlined", 'I check it once, then I check it twice, oh!', '[Chorus]', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me—', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me do', '[Verse 2]', "I don't like your kingdom keys", 'They once belonged to me', 'You asked me for a place to sleep', 'Locked me out and threw a feast (What?)', 'The world moves on, another day, another drama, drama', 'But not for me, not for me, all I think about is karma', "And then the world moves on, but one thing's for sure", "Maybe I got mine, but you'll all get yours", '[Pre-Chorus]', 'But I got smarter, I got harder in the nick of time', 'Honey, I rose up from the dead, I do it all the time', "I've got a list of names and yours is in red, underlined", 'I check it once, then I check it twice, oh!', '[Chorus]', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me—', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me do', '[Bridge]', "I don't trust nobody and nobody trusts me", "I'll be the actress starring in your bad dreams", "I don't trust nobody and nobody trusts me", "I'll be the actress starring in your bad dreams", "I don't trust nobody and nobody trusts me", "I'll be the actress starring in your bad dreams", "I don't trust nobody and nobody trusts me", "I'll be the actress starring in your bad dreams", '(Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me—', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me—)', 'I\'m sorry, the old Taylor can\'t come to the phone right now\t62\t2017-08-25\n1\treputation\tLook What You Made Me Do \tWhy? Oh, \'cause she\'s dead!" (Oh)', '[Chorus]', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me—', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me do', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me—', 'Ooh, look what you made me do', 'Look what you made me do', 'Look what you just made me do', 'Look what you just made me do']

# %%
vectorizer = TfidfVectorizer(stop_words = 'english', min_df = 2)

# %%
#code from 4300 class demo
word_splitter = re.compile(r"""
    (\w+)
    """, re.VERBOSE)

def getwords(lyric):
  return [w.lower() for w in word_splitter.findall(lyric)]

# %%
lyrics_list = []
for i in index_dic:
    lyric = index_dic[i]
    lyric_str = ""
    for l in lyric:
        l.lower()
        lyric_str += " "
        lyric_str += l
    all_words = getwords(lyric_str)
    lyrics_list.append(" ".join(all_words))
print(lyrics_list[0])
print(len(lyrics_list))
# Out:
# verse 1 we could leave the christmas lights up til january and this is our place we make the rules and there s a dazzling haze a mysterious way about you dear have i known you 20 seconds or 20 years chorus can i go where you go can we always be this close forever and ever ah take me out and take me home you re my my my my lover verse 2 we could let our friends crash in the living room this is our place we make the call and i m highly suspicious that everyone who sees you wants you i ve loved you three summers now honey but i want em all chorus can i go where you go can we always be this close forever and ever ah take me out and take me home forever and ever you re my my my my lover bridge ladies and gentlemen will you please stand with every guitar string scar on my hand i take this magnetic force of a man to be my lover my heart s been borrowed and yours has been blue all s well that ends well to end up with you swear to be overdramatic and true to my lover and you ll save all your dirtiest jokes for me and at every table i ll save you a seat lover chorus can i go where you go can we always be this close forever and ever ah take me out and take me home forever and ever you re my my my my oh you re my my my my darling you re my my my my lover
# 343

# %%
tfidf_vec = vectorizer.fit_transform(lyrics_list).toarray()

# %%
print(sum(tfidf_vec))
# Out:
# [0.05411225 0.38995259 2.34563354 ... 1.5257614  1.51963972 0.10571972]

# %%
print(num_songs)
print(tfidf_vec.shape)
# Out:
# 343
# (343, 2728)

# %%
cos_sim = np.zeros((num_songs,num_songs))
i = 0
while i < num_songs:
    j = 0
    while j < num_songs:
        song1 = tfidf_vec[i]
        song2 = tfidf_vec[j]
        song1_norm = np.linalg.norm(tfidf_vec[i])
        song2_norm = np.linalg.norm(tfidf_vec[j])
        numerator = np.dot(song1, song2)
        denominator = song1_norm * song2_norm
        cosine_similarity = numerator/denominator
        cos_sim[i][j] = cosine_similarity
        j += 1
    i += 1

# %%
print(cos_sim[100][331])
# Out:
# 0.061633256458969984

# %%
np.save('cosine_matrix', cos_sim)
